# %%
import pandas as pd
import json
import threading
import requests

from io import StringIO

from datetime import date
from datetime import timedelta

import stocks
import importlib
importlib.reload(stocks) # every run

from stocks import Stock

import time
'''
tic = time.perf_counter()
    --function to time here--
toc = time.perf_counter()
print(f"Downloaded the tutorial in {toc - tic:0.4f} seconds")
'''

#api_key='OeAFFmMliFG5orCUuwAKQ8l4WWFQ67YX'
api_key='604f9349dd39a0.52974186'
# Out:
# Exception in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException ignored in sys.unraisablehookException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException ignored in sys.unraisablehookException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException in thread Exception in threading.excepthook:Exception ignored in thread started byException ignored in sys.unraisablehookException in thread Exception in threading.excepthook:Exception ignored in thread started byException ignored in sys.unraisablehookException in thread Exception in threading.excepthook:Exception ignored  ...

# %%
def get_files(path):
    return set(os.path.splitext(filename)[0] for filename in os.listdir(path))

# %%
def save_json(data,name):
    path = f'./data/{name}.json'
    with open(path, 'w') as json_file:
        json.dump(data, json_file)

# %%
def get_api_data(url,params,session=None):
    if session is None:
        session = requests.Session()
        r = session.get(url, params=params)
        if r.status_code == requests.codes.ok:
            return r.text
        else:
            print(f'problem with: {url}, {params}')

def get_fundamentals_data(symbol='AAPL', api_token=api_key):
    url = f'https://eodhistoricaldata.com/api/fundamentals/{symbol}.US'
    params = {'api_token': api_token}
    data = get_api_data(url=url,params=params)
    save_json(data=data,name=symbol)
    return data

def get_eod_data(symbol='AAPL', api_token=api_key):
    url = f'https://eodhistoricaldata.com/api/eod/{symbol}'
    params = {'api_token': api_token, 'order': 'd', 'fmt': 'csv'}
    data = get_api_data(url=url,params=params)
    df = pd.read_csv(StringIO(data), skipfooter=1, parse_dates=[0], index_col=False, engine='python')
    df.to_csv(f'./EOD/{symbol}.csv', index=False)
    return df

# %%
tickersdf=pd.read_csv('US_LIST_OF_SYMBOLS.csv')
symbols=set(tickersdf.loc[tickersdf['Type']=='Common Stock',['Code']]['Code'])
dataFiles = get_files('./data')
eodFiles = get_files('./EOD')
dataMiss=symbols-dataFiles
eodMiss=symbols-eodFiles

# %%
extra=dataFiles-eodFiles
for file in extra:
    os.rename(f'./data/{file}.json',f'./backup/data/{file}.json')

# %%
def mainGetData(symbol):
    #get_eod_data(symbol)
    get_fundamentals_data(symbol)

if __name__ == '__main__':
    for symbol in dataMiss:
        t = threading.Thread(target=mainGetData, args=(symbol,))
        t.start()
# Out:
# problem with: https://eodhistoricaldata.com/api/fundamentals/TLTZY.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/SARSF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/IGEN.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/DAPXX.US, {'api_token': '604f9349dd39a0.52974186'}problem with: https://eodhistoricaldata.com/api/fundamentals/ADIA.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/PSSGF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/FPMI.US, {'api_token': '604f9349dd39a0.52974186'}
#
# problem with: https://eodhistoricaldata.com/api/fundamentals/STTDF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/IGGGF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/SLGD.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/GENGF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/MONOY.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/TRGCF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/ADDC.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/ANDR.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/SOUPQ.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/TORDF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/PRIEF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/SRWRF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/CITAY.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/FCRM.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/NWHAF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/ITSPF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/OCLN.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/PTGEF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/CLOW.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/BLIS.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/TGGDF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/BLRS.US, {'api_token': '604f9349dd39a0.52974186'}problem with: https://eodhistoricaldata.com/api/fundamentals/SCVPF.US, {'api_token': '604f9349dd39a0.52974186'}
#
# problem with: https://eodhistoricaldata.com/api/fundamentals/CHCLY.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/DSCR.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/KXSCF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/NEXJF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/AHKSY.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/HYII.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/ASBRY.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/SCWTF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/VBTC.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/DWOG.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/XDSL.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/RCTUF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/CDNO.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/VIGLF.US, {'api_token': '604f9349dd39a0.52974186'}problem with: https://eodhistoricaldata.com/api/fundamentals/AKEJF.US, {'api_token': '604f9349dd39a0.52974186'}
#
# problem with: https://eodhistoricaldata.com/api/fundamentals/JGLDF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/UNEX.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/FSNJ.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/JADG.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/SYNI.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/EUBG.US, {'api_token': '604f9349dd39a0.52974186'}problem with: https://eodhistoricaldata.com/api/fundamentals/RSAIF.US, {'api_token': '604f9349dd39a0.52974186'}problem with: https://eodhistoricaldata.com/api/fundamentals/PRWYF.US, {'api_token': '604f9349dd39a0.52974186'}problem with: https://eodhistoricaldata.com/api/fundamentals/PAYD.US, {'api_token': '604f9349dd39a0.52974186'}
#
#
#
# problem with: https://eodhistoricaldata.com/api/fundamentals/MGYTF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/SVSE.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/QWTR.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/NTDOF.US, {'api_token': '604f9349dd39a0.52974186'}problem with: https://eodhistoricaldata.com/api/fundamentals/LLNKD.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/TEGY.US, {'api_token': '604f9349dd39a0.52974186'}
#
# problem with: https://eodhistoricaldata.com/api/fundamentals/XLRM.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/ONMBF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/MMRGF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/UMAM.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/AMIVF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/EVKIF.US, {'api_token': '604f9349dd39a0.52974186'}problem with: https://eodhistoricaldata.com/api/fundamentals/SMECF.US, {'api_token': '604f9349dd39a0.52974186'}
#
# problem with: https://eodhistoricaldata.com/api/fundamentals/POSC.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/CSBF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/BFARF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/PLPL.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/DEQI.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/MPEG.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/AMYZF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/UBSFY.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/RSKIA.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/ADVV.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/TNJIF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/LMSC.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/HLFN.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/NXMR.US, {'api_token': '604f9349dd39a0.52974186'}problem with: https://eodhistoricaldata.com/api/fundamentals/PV-WS.US, {'api_token': '604f9349dd39a0.52974186'}
#
# problem with: https://eodhistoricaldata.com/api/fundamentals/PAEKY.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/CPSO.US, {'api_token': '604f9349dd39a0.52974186'}

# %%
async def load_json(ticker):
    path = f'./data/{ticker}.json'
    print(path)
    async with aiofiles.open(path, mode='r') as json_file:
        content = await json_file.read()
        return(content)

async def mainReadFiles():
    data = await load_json('WLKP')
    data = json.loads(data)
    
    stock = Stock(ticker='WLKP', data=data)
    return stock.mainYr

loop = asyncio.get_event_loop()
loop.run_until_complete(mainReadFiles())
# Out:
# problem with: https://eodhistoricaldata.com/api/fundamentals/IRIDQ.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/TOTA.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/ASWRF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/GVFG.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/HOKCF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/PNGZF.US, {'api_token': '604f9349dd39a0.52974186'}
# problem with: https://eodhistoricaldata.com/api/fundamentals/LPMDF.US, {'api_token': '604f9349dd39a0.52974186'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-aa88a8626da0> in <module>
#      13     return stock.mainYr
#      14
# ---> 15 loop = asyncio.get_event_loop()
#      16 loop.run_until_complete(mainReadFiles())
#
# NameError: name 'asyncio' is not defined
