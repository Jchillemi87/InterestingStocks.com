# %%
import pandas as pd
import json
import threading
import requests
from requests.exceptions import HTTPError

from io import StringIO

from datetime import date
from datetime import timedelta

import stocks
import importlib
importlib.reload(stocks) # every run

from stocks import Stock

import time
'''
tic = time.perf_counter()
    --function to time here--
toc = time.perf_counter()p
print(f"Downloaded the tutorial in {toc - tic:0.4f} seconds")
'''

#api_key='OeAFFmMliFG5orCUuwAKQ8l4WWFQ67YX'
api_key='604f9349dd39a0.52974186'

# %%
def get_files(path):
    return set(os.path.splitext(filename)[0] for filename in os.listdir(path))

# %%
def save_json(data,name):
    path = f'./data/{name}.json'
    print(data)
    with open(path, 'w') as json_file:
        json_file.write(data)
        #json.dump(data, json_file, ensure_ascii=False)

# %%
def get_api_data(url,params,session=None):
    if session is None:
        session = requests.Session()
        try:
            response = session.get(url, params=params)
            
            # If the response was successful, no Exception will be raised
            response.raise_for_status()
        except HTTPError as http_err:
            print(f'HTTP error occurred: {http_err}\nproblem with: {url}, {params}')
        except Exception as err:
            print(f'Other error occurred: {err}\nproblem with: {url}, {params}')  # Python 3.6
        else:
            #if r.status_code == requests.codes.ok:
            return response.text
                

def get_fundamentals_data(symbol='AAPL', api_token=api_key):
    url = f'https://eodhistoricaldata.com/api/fundamentals/{symbol}.US'
    params = {'api_token': api_token}
    data = get_api_data(url=url,params=params)
    save_json(data=data,name=symbol)
    return data

def get_eod_data(symbol='AAPL', api_token=api_key):
    url = f'https://eodhistoricaldata.com/api/eod/{symbol}'
    params = {'api_token': api_token, 'order': 'd', 'fmt': 'csv'}
    data = get_api_data(url=url,params=params)
    df = pd.read_csv(StringIO(data), skipfooter=1, parse_dates=[0], index_col=False, engine='python')
    df.to_csv(f'./EOD/{symbol}.csv', index=False)
    return df

# %%
tickersdf=pd.read_csv('US_LIST_OF_SYMBOLS.csv')
symbols=set(tickersdf.loc[tickersdf['Type']=='Common Stock',['Code']]['Code'])
dataFiles = get_files('./data')
eodFiles = get_files('./EOD')
dataMiss=symbols-dataFiles
eodMiss=dataFiles-eodFiles

# %%
#extra=dataFiles-eodFiles
#for file in extra:
#    os.rename(f'./data/{file}.json',f'./backup/data/{file}.json')

# %%
def mainGetData(symbol):
    get_eod_data(symbol)
    #get_fundamentals_data(symbol)


if __name__ == '__main__':
#    get_fundamentals_data(symbol='aapl')
    api_limiter=500000
    #dataMiss=['KSS','WLKP','FL','DAL','MO','CCL','T','TPR','PFG','WFC']
    for symbol in eodMiss:
        if(api_limiter>0):
            api_limiter-=1
            t = threading.Thread(target=mainGetData, args=(symbol,))
            t.start()
# Out:
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/FCREY?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/FCREY, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/LPI?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/LPI, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/FSRVW?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/FSRVW, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/BB?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/BB, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/CNNC?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/CNNC, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/GNGXF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/GNGXF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/HNTIY?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/HNTIY, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/HENI?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/HENI, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/HLYK?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/HLYK, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/FVRG?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/FVRG, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/FMC?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/FMC, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/ASBRY?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/ASBRY, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/IDKFF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/IDKFF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/AAIIQ?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/AAIIQ, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
#
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/TMAK?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/TMAK, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/ABPR?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/ABPR, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/NNSV?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/NNSV, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/GCLL?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/GCLL, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/NDRBF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/NDRBF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/ATHM?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/ATHM, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/LMNR?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/LMNR, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/EUSP?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/EUSP, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/FCBBF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/FCBBF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/CHDGF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/CHDGF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/HLXA?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/HLXA, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/WNRS?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/WNRS, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/WFTUF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/WFTUF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/SHNL?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/SHNL, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/AIRTW?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/AIRTW, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/EGYF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/EGYF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/XIORF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/XIORF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/ARET?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/ARET, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/LMRMF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/LMRMF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/ARPC?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/ARPC, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/MLOOF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/MLOOF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/CRNZF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/CRNZF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/UTGN?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/UTGN, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# Exception in thread Thread-617:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/GWOX?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/GWOX, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/DRCR?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/DRCR, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/KPIFF?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/KPIFF, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/GRYN?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/GRYN, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/SRSR?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/SRSR, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
# HTTP error occurred: 429 Client Error: Too Many Requests for url: https://eodhistoricaldata.com/api/eod/MIK?api_token=604f9349dd39a0.52974186&order=d&fmt=csv
# problem with: https://eodhistoricaldata.com/api/eod/MIK, {'api_token': '604f9349dd39a0.52974186', 'order': 'd', 'fmt': 'csv'}
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread Thread-545:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
# Exception in thread Thread-548:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
# Exception in thread Thread-508:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#         orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
# orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     self._target(*self._args, **self._kwargs)return next(self.data)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
# Exception in thread   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Thread-553:
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#       File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     self._target(*self._args, **self._kwargs)return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#       File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
# return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#             self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
# return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
# self._target(*self._args, **self._kwargs)        self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
# self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#       File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
# ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors    ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# .EmptyDataError: No columns to parse from file
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread Thread-604:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread Thread-624:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
# Exception in thread Thread-621:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
# Exception in thread     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     Thread-616:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
# return next(self.data)    parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#
# StopIteration    self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#         return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
# parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#         self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
# raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread Exception in thread Thread-635:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
# Thread-642:
# Traceback (most recent call last):
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#         orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
# line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#         self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
# self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)    ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread Thread-657:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread Thread-549:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
# Exception in thread     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
# Thread-554:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
# Exception in thread Thread-558:
# Traceback (most recent call last):
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#         self._target(*self._args, **self._kwargs)
#       File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
# line = self._buffered_line()return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#       File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
# self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#       File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
# self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#         return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
# self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#         parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
# self._make_engine(self.engine)    raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread
# Thread-559:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread Thread-620:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread Thread-569:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
# Exception in thread Thread-564:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     line = self._buffered_line()    return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#         parser = TextFileReader(fp_or_buf, **kwds)self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#         self._engine = klass(self.f, **self.options)
# ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread Thread-571:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread Thread-563:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file
# Exception in thread Thread-573:
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2683, in _infer_columns
#     line = self._buffered_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2859, in _buffered_line
#     return self._next_line()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2956, in _next_line
#     orig_line = self._next_iter_line(row_num=self.pos + 1)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 3014, in _next_iter_line
#     return next(self.data)
# StopIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/joseph/anaconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-8-68f9835b5901>", line 2, in mainGetData
#   File "<ipython-input-6-ac8a8b3d8255>", line 29, in get_eod_data
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 946, in __init__
#     self._make_engine(self.engine)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 1189, in _make_engine
#     self._engine = klass(self.f, **self.options)
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2405, in __init__
#     ) = self._infer_columns()
#   File "/home/joseph/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 2705, in _infer_columns
#     raise EmptyDataError("No columns to parse from file") from err
# pandas.errors.EmptyDataError: No columns to parse from file

# %%
async def load_json(ticker):
    path = f'./data/{ticker}.json'
    print(path)
    async with aiofiles.open(path, mode='r') as json_file:
        content = await json_file.read()
        return(content)

async def mainReadFiles():
    data = await load_json('WLKP')
    data = json.loads(data)
    
    stock = Stock(ticker='WLKP', data=data)
    return stock.mainYr

loop = asyncio.get_event_loop()
loop.run_until_complete(mainReadFiles())
